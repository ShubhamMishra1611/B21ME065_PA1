# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa

import pandas as pd
from EchoLib import *

from ipywidgets import interact

# %%
WindowFunction.show_window(WindowFunction.hann)

# %%
processor = AudioProcessor(r'7061-6-0-0')
testaudio, testsr = processor._load_audio()
testaudio.shape, testsr
# Out:
# ((99225,), 44100)

# %%
processor.plot_waveform()

# %%
stft_processor = STFTProcessor(testaudio, testsr, WindowFunction.hann)
s = stft_processor.compute_stft(fixed=True)
plt.imshow(np.log(np.absolute(s))*20, cmap='inferno', aspect=(s.shape[1]/s.shape[0]))
plt.show()
# Out:
# 99180/99225...

# %%
audio_analyser = AudioAnalyzer('9031-3-2-0')
audio_analyser.analyze()
# Out:
# 100833/101324...
